# %% [markdown]
# # GRIP-The Sparks Foundation

# %% [markdown]
# # Data Science and Business Analytics

# %% [markdown]
# # Author-Bhavana Ananthula

# %% [markdown]
# # TASK 3-Exploratory Data Analysis-Retail

# %% [markdown]
# **Importing Libraries**

# %%
### Import all necessary Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# To ignore the warnings 
import warnings as wg
wg.filterwarnings("ignore")

# %%
#Reading the Dataset
sample = pd.read_csv("SampleSuperstore.csv")
sample.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
sample.shape
# Out:
# (9994, 13)

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
sample.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#Checking Missing Values
sample.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# Checking the dupilication in data
sample.duplicated().sum()
# Out:
# 17

# %%
sample.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
sample.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#Deleting the Variable.
col=['Postal Code']
sample1=sample.drop(columns=col,axis=1)

# %%
#Correlation Between Variables.
sample1.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
# Covariance of columns
sample1.cov()
# Out:
#                   Sales    Quantity   Discount        Profit
# Sales     388434.455308  278.459923  -3.627228  69944.096586
# Quantity     278.459923    4.951113   0.003961     34.534769
# Discount      -3.627228    0.003961   0.042622    -10.615173
# Profit     69944.096586   34.534769 -10.615173  54877.798055

# %%
sample1.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category', data=sample1)
plt.title('Category vs Sub Category')
plt.xlabel('Sub-Catgory')
plt.ylabel('Category')
plt.xticks(rotation=45)
plt.show()

# %%
# visualizing the dataset as a whole using the pair plot
import seaborn as sns 
sns.pairplot(sample)

# %%
# finding the pairwise correlations between the columns and visualising using heatmaps
sample.corr()
plt.figure(figsize=(10,5))
sns.heatmap(sample.corr(), annot=True)
plt.show()

# %%
plt.figure(figsize = (6,6))
textprops = {"fontsize":15}
plt.title('Category')
plt.pie(sample['Category'].value_counts(), labels=sample['Category'].value_counts().index,autopct='%1.1f%%',textprops = textprops)
plt.show()

# %%
plt.figure(figsize= (10,16))
sample.groupby('Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.ylabel('Profit')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(2, figsize=(20,15))
sns.barplot(x='Sub-Category',y='Profit', data=sample, palette='Spectral')
plt.suptitle('Pie Consumption Patterns in the United States', fontsize=16)
plt.show()

# %%
# computing top categories in terms of sales from first 100 observations
top_category_s = sample.groupby("Category").Sales.sum().nlargest(n=100)
# computing top categories in terms of profit from first 100 observations
top_category_p = sample.groupby("Category").Profit.sum().nlargest(n=100)

# plotting to see it visually
plt.style.use('seaborn')
top_category_s.plot(kind = 'bar',figsize = (10,5),fontsize = 14)
top_category_p.plot(kind = 'bar',figsize = (10,5),fontsize = 14,color='red')
plt.xlabel('Category',fontsize = 15)
plt.ylabel('Total Sales/Profits',fontsize = 15)
plt.title("Top Category Sales vs Profit",fontsize = 15)
plt.show()

# %%
# computing top sub-categories in terms of sales from first 100 observations
top_subcategory_s = sample.groupby("Sub-Category").Sales.sum().nlargest(n = 100)
# computing top sub-categories in terms of profit from first 100 observations
top_subcategory_p = sample.groupby("Sub-Category").Profit.sum().nlargest(n = 100)

# plotting to see it visually
plt.style.use('seaborn')
top_subcategory_s.plot(kind = 'bar',figsize = (10,5),fontsize = 14)
top_subcategory_p.plot(kind = 'bar',figsize = (10,5),fontsize = 14, color = 'red')
plt.xlabel('Sub-Category',fontsize = 15)
plt.ylabel('Total Sales/Profits',fontsize = 15)
plt.title("Top Sub-Category Sales vs Profit",fontsize = 15)
plt.show()

# %%
# A more detailed view
plt.figure(figsize=(14,12))
statewise = sample.groupby(['Sub-Category'])['Profit'].sum().nlargest(50)
statewise.plot.barh() # h for horizontal
# Out:
# <AxesSubplot:ylabel='Sub-Category'>

# %% [markdown]
# **The above graph clearly shows that Copiers and Phones have the highest sales and profit and tables has negative profit**

# %% [markdown]
# # Visualising the discount

# %%
plt.figure(figsize=(8,7))
sns.lineplot(sample['Discount'], sample['Profit'], data=sample)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %% [markdown]
# # Visualizing the Sales vs Profits in different Regions

# %%
plt.figure(figsize = (6,6))
plt.title('Region')
plt.pie(sample['Region'].value_counts(), labels=sample['Region'].value_counts().index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# **The graph shows that West and East have same Profit though sales in the East are less as compared to West.**

# %% [markdown]
# # Visualising the Sales vs Profits in different states

# %%
# computing top states in terms of sales from first 10 observations
top_states_s = sample.groupby("State").Sales.sum().nlargest(n=10)

# computing top states in terms of profit from first 10 observations
top_states_p = sample.groupby("State").Profit.sum().nlargest(n = 10)

plt.style.use('seaborn')
top_states_s.plot(kind = 'bar',figsize = (10,5),fontsize = 14)
top_states_p.plot(kind = 'bar',figsize = (10,5),fontsize = 14, color = 'red')
plt.xlabel('States',fontsize = 15)
plt.ylabel('Total sales',fontsize = 15)
plt.title("Top 10 states Sales vs Profit",fontsize = 15)
plt.show()

# %% [markdown]
# # Checking the interdependency of Sales,Profits and Discounts

# %%
plt.style.use('seaborn')
sample.plot(kind = "scatter",figsize = (10,5), x = "Sales", y= "Profit", c = "Discount", s = 20,fontsize = 16, colormap = "viridis")
plt.ylabel('Total Profits',fontsize = 16)
plt.title("Interdependency of Sales,Profits and Discounts",fontsize = 16)

plt.show()

# %%
data1= sample.groupby("State")[["Sales","Profit"]].sum().sort_values(by="Sales", ascending=False)
data1[:].plot.bar(color = ["pink","Red"], figsize=(20,12))
plt.title("Profit-Loss and Sales across States")
plt.show()

# %% [markdown]
# **California generate more profit compared to the other states.**

# %%
sample.hist(figsize=(10,10), bins= 50,color="purple")
plt.show()

# %%
p = sns.FacetGrid(sample, col ='Category')
p.map(plt.hist, 'Profit',color="orange")

# %% [markdown]
# **Maximum profit is in Office supplies.**

# %%
res9 = sample.groupby('Discount').sum()
res9.loc[:,'Sales']
dis = [ dis for dis, sample in sample.groupby('Discount')]
plt.figure(figsize = (15,8))
sns.lineplot(dis,res9['Profit'], color = 'pink', marker = "*", markersize = 15, markerfacecolor = 'darkblue', linewidth = 5)
plt.title('Discount vs Sales', fontsize = 20, fontweight = 'bold')
plt.xlabel('Discount', fontsize = 15)
plt.ylabel('Sales', fontsize = 15)
plt.show()

# %% [markdown]
# **From the above plot, we can infer that, the discount range of 0% that is, 0.0 gives more sales. Secondly, the discount range of 20% that is, 0.2 gives moderate sales.**

# %% [markdown]
# # Conclusion:

# %% [markdown]
# **1)From the above analysis, we can conclude that, 0% discount gives moderate sales with more profit and 20% discount gives provides more sales with moderate quantity.**
#
# **2)California, Washington and NewYork generates the most sales compared to the other places.**
#
# **3)The Western region generates highest profit.**
#
# **4)The Central region generates lowest profit.**
#
# **5)Texas, Florida,Pennsylvenia, Illinois, Ohio and some other states are generating loss with high sale. Hence, we need to give focus and attention towards them.**
#
# **6)Also, when there are no heavy discounts, there won't be much loss in profit and increases the profit and sales as expected. Since, 0% discount provides sell sales with more quantity and more profit. Hence, I recommend to sell products at 0% discount, that is products with no discount at lowest price which makes more sales and more profit to the organization.**
